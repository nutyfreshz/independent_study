# %% [markdown]
# <a href="https://colab.research.google.com/github/nutyfreshz/independent_study/blob/main/Markrov's_Chain_Py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Preparation

# %% [markdown]
# SQL:
#
#
# ```
# --Markov's chain last 1 years as of 24/12/23
#
# WITH cal AS
# (SELECT sales.trans_date AS "date"
# 		, sales.member_number
# 		, prod.brand_name
# 		, sum(sales.net_price_tot) sale
# FROM analysis_cds_rbs.sales_sku_cds_rbs sales
# JOIN analysis_cds_rbs.ca_ds_ms_product prod
# 	USING(sku_id)
# WHERE 1=1
# 	AND sales.member_number IS NOT NULL
# 	AND prod.dept_name IN ('BEAUTY') AND prod.class_name IN ('SKINCARE')
# 	AND date(sales.trans_date) BETWEEN DATEADD(YEAR,-1,GETDATE())+1 AND GETDATE()
# GROUP BY 1,2,3
# )
#
# , cal_tot AS
# (SELECT  t1.brand_name AS brand_from
# 		, t2.brand_name AS brand_to
# 		, count(t1.member_number) cnt
# FROM cal t1, cal t2
# WHERE 1=1
# 	AND t1.member_number = t2.member_number
# 	AND t1."date" < t2."date"
# GROUP BY 1,2
# ORDER BY 1,2
# )
#
# , fin_matrix AS
# (SELECT brand_from
# 		, brand_to
# 		, cnt
# 		, sum(cnt) OVER(PARTITION BY brand_from) cnt_total
# FROM cal_tot
# GROUP BY 1,2,3
# ORDER BY 1,2
# )
#
# SELECT brand_from
# 		, brand_to
# 		, cnt/cnt_total::DECIMAL(38,5) AS prob
# FROM fin_matrix
#
# ;
# ```

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/content/extra_markrov.xlsx', sheet_name = 'all')
df
# Out:
#             brand_from         brand_to      prob
# 0      ACQUA ALLE ROSE  ACQUA ALLE ROSE  0.093750
# 1      ACQUA ALLE ROSE               AR  0.006250
# 2      ACQUA ALLE ROSE      BANANA BOAT  0.006250
# 3      ACQUA ALLE ROSE           BEAVER  0.018750
# 4      ACQUA ALLE ROSE          BENEFIT  0.025000
# ...                ...              ...       ...
# 23219           ZELENS            THREE  0.017065
# 23220           ZELENS          VALMONT  0.001706
# 23221           ZELENS             WHOO  0.013652
# 23222           ZELENS              YSL  0.001706
# 23223           ZELENS           ZELENS  0.025597
#
# [23224 rows x 3 columns]

# %% [markdown]
# # Predicting Future States

# %% [markdown]
# ## Create Transition Matrix

# %%
# Get unique brands
unique_brands = sorted(set(df['brand_from']).union(set(df['brand_to'])))

# Create transition matrix with zeros
num_brands = len(unique_brands)
transition_matrix = np.zeros((num_brands, num_brands))

# Fill transition matrix based on probabilities
for index, row in df.iterrows():
    from_index = unique_brands.index(row['brand_from'])
    to_index = unique_brands.index(row['brand_to'])
    transition_matrix[from_index][to_index] = row['prob']

# Normalize transition matrix
transition_matrix = transition_matrix / transition_matrix.sum(axis=1, keepdims=True)

print("Transition Matrix:")
print(transition_matrix)
# Out:
# Transition Matrix:
# [[9.37500000e-02 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 6.76157030e-01 0.00000000e+00 ... 0.00000000e+00
#   1.37965630e-03 1.25423300e-04]
#  [0.00000000e+00 2.91241940e-03 4.24381111e-02 ... 0.00000000e+00
#   1.66423970e-03 0.00000000e+00]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 1.00000000e-01
#   0.00000000e+00 0.00000000e+00]
#  [5.77767999e-05 2.88883799e-04 0.00000000e+00 ... 0.00000000e+00
#   1.20522302e-01 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   1.70648460e-03 2.55972696e-02]]
# <ipython-input-3-00607aab9863>:15: RuntimeWarning: invalid value encountered in divide
#   transition_matrix = transition_matrix / transition_matrix.sum(axis=1, keepdims=True)

# %% [markdown]
# ## Troubleshooting before run Matrix
#
# '''Before run next prob: Must No NaN or Inf both 2 matrix'''

# %%
# Ensure 'unique_brands' includes 'SHISEIDO'
shiseido_index = unique_brands.index('SHISEIDO')

# Extract the row for SHISEIDO from the transition matrix
shiseido_probs = transition_matrix[shiseido_index]

# Ensure the 'shiseido_probs' vector and 'transition_matrix' are correctly shaped
print("Shape of shiseido_probs:", shiseido_probs.shape)
print("Shape of transition_matrix:", transition_matrix.shape)

# Check for zeros in 'shiseido_probs' vector or 'transition_matrix'
print("Zeros in shiseido_probs:", np.count_nonzero(shiseido_probs == 0))
print("Zeros in transition_matrix:", np.count_nonzero(transition_matrix == 0))

# Check for NaN or infinite values in 'shiseido_probs' or 'transition_matrix'
print("NaN in shiseido_probs:", np.isnan(shiseido_probs).any())
print("NaN in transition_matrix:", np.isnan(transition_matrix).any())
print("Infinite values in shiseido_probs:", not np.isfinite(shiseido_probs).all())
print("Infinite values in transition_matrix:", not np.isfinite(transition_matrix).all())

# Normalize 'shiseido_probs' to handle any zero division issues
shiseido_probs_normalized = shiseido_probs / np.sum(shiseido_probs)
print("Normalized shiseido_probs:", shiseido_probs_normalized)

# %% [markdown]
# ## Manipulate Data into Calculatable form

# %%
# Addressing zero probabilities and NaN/infinite values
epsilon = 1e-8  # Small non-zero value

# Adding epsilon to transition_matrix to handle zero probabilities
transition_matrix_smoothed = transition_matrix + epsilon

# Replacing NaN or infinite values in transition_matrix with zeros or other suitable values
transition_matrix_smoothed[~np.isfinite(transition_matrix_smoothed)] = 0  # Replace NaN/infinite values with 0

# Index of 'SHISEIDO' in the unique brands list
shiseido_index = unique_brands.index('SHISEIDO')

# Extract the row for SHISEIDO from the smoothed transition matrix
shiseido_probs_smoothed = transition_matrix_smoothed[shiseido_index]

# Add epsilon to shiseido_probs to handle zero probabilities
shiseido_probs_smoothed += epsilon

# Normalize 'shiseido_probs_smoothed' after handling zeros
shiseido_probs_normalized = shiseido_probs_smoothed / np.sum(shiseido_probs_smoothed)

# Predict future states (next time step) using the normalized 'shiseido_probs_normalized' and 'transition_matrix_smoothed'
next_state_vector_shiseido = np.dot(shiseido_probs_normalized, transition_matrix_smoothed)
print("Next State Probabilities for SHISEIDO (t+1):", next_state_vector_shiseido)

# %%
# Assuming next_state_vector_shiseido is your array
highest_prob_indices = np.argsort(-next_state_vector_shiseido)[:5]  # Get indices of top 5 highest probabilities
highest_probabilities = next_state_vector_shiseido[highest_prob_indices]

# Display top 5 highest probabilities and their corresponding indices (brands/states)
for i, index in enumerate(highest_prob_indices):
    print(f"Brand/State Index: {index}, Probability: {highest_probabilities[i]}")
# Out:
# Brand/State Index: 232, Probability: 0.18513758641856873
# Brand/State Index: 145, Probability: 0.12645930561873053
# Brand/State Index: 41, Probability: 0.07401806615758386
# Brand/State Index: 64, Probability: 0.056482036347445135
# Brand/State Index: 39, Probability: 0.04883585629908949

# %%
# Assuming next_state_vector_shiseido is your array
highest_prob_indices = np.argsort(-next_state_vector_shiseido)[:5]  # Get indices of top 5 highest probabilities
highest_probabilities = next_state_vector_shiseido[highest_prob_indices]

# Map indices to brand names
index_to_brand = {index: brand_name for index, brand_name in enumerate(unique_brands)}

# Display top 5 highest probabilities and their corresponding brands
for i, index in enumerate(highest_prob_indices):
    brand_name = index_to_brand.get(index, "Unknown Brand")
    print(f"Brand: {brand_name}, Probability: {highest_probabilities[i]}")
# Out:
# Brand: SHISEIDO, Probability: 0.18513758641856873
# Brand: KIEHLS, Probability: 0.12645930561873053
# Brand: BOBBI BROWN, Probability: 0.07401806615758386
# Brand: CLARINS, Probability: 0.056482036347445135
# Brand: BIOTHERM, Probability: 0.04883585629908949

# %% [markdown]
# # Essemble Code into Function

# %%
def markrov_brand(brand_name):
  # Get unique brands
  unique_brands = sorted(set(df['brand_from']).union(set(df['brand_to'])))

  # Create transition matrix with zeros
  num_brands = len(unique_brands)
  transition_matrix = np.zeros((num_brands, num_brands))

  # Fill transition matrix based on probabilities
  for index, row in df.iterrows():
    from_index = unique_brands.index(row['brand_from'])
    to_index = unique_brands.index(row['brand_to'])
    transition_matrix[from_index][to_index] = row['prob']

  # Addressing zero probabilities and NaN/infinite values

  epsilon = 1e-8  # Small non-zero value

  transition_matrix = transition_matrix / (transition_matrix.sum(axis=1, keepdims=True) + epsilon)

  ############################################################

  # Adding epsilon to transition_matrix to handle zero probabilities
  transition_matrix_smoothed = transition_matrix

  # Replacing NaN or infinite values in transition_matrix with zeros or other suitable values
  transition_matrix_smoothed[~np.isfinite(transition_matrix_smoothed)] = 0  # Replace NaN/infinite values with 0

  # Index of 'SHISEIDO' in the unique brands list
  shiseido_index = unique_brands.index(brand_name)

  # Extract the row for SHISEIDO from the smoothed transition matrix
  shiseido_probs_smoothed = transition_matrix_smoothed[shiseido_index]

  # Add epsilon to shiseido_probs to handle zero probabilities
  shiseido_probs_smoothed += epsilon

  # Normalize 'shiseido_probs_smoothed' after handling zeros
  shiseido_probs_normalized = shiseido_probs_smoothed / np.sum(shiseido_probs_smoothed)

  # Predict future states (next time step) using the normalized 'shiseido_probs_normalized' and 'transition_matrix_smoothed'
  next_state_vector_shiseido = np.dot(shiseido_probs_normalized, transition_matrix_smoothed)

  ############################################################

  # Assuming next_state_vector_shiseido is your array
  highest_prob_indices = np.argsort(-next_state_vector_shiseido)[:5]  # Get indices of top 5 highest probabilities
  highest_probabilities = next_state_vector_shiseido[highest_prob_indices]

  # Map indices to brand names
  index_to_brand = {index: brand_name for index, brand_name in enumerate(unique_brands)}

  # Display top 5 highest probabilities and their corresponding brands
  for i, index in enumerate(highest_prob_indices):
    brand_name = index_to_brand.get(index, "Unknown Brand")
    print(f"Brand: {brand_name}, Probability: {highest_probabilities[i]}")

# %%
markrov_brand('SHISEIDO')
# Out:
# Brand: SHISEIDO, Probability: 0.1851380426265176
# Brand: KIEHLS, Probability: 0.12645958620697365
# Brand: BOBBI BROWN, Probability: 0.07401822497678473
# Brand: CLARINS, Probability: 0.05648209433883934
# Brand: BIOTHERM, Probability: 0.04883595808477725

# %%
markrov_brand('CHANEL')
# Out:
# Brand: CHANEL, Probability: 0.08824337302081975
# Brand: DIOR, Probability: 0.08673854990925016
# Brand: KIEHLS, Probability: 0.07578116746359724
# Brand: CLARINS, Probability: 0.06497838480027622
# Brand: LOCCITANE, Probability: 0.0638198357087771

# %%
markrov_brand('DIOR')
# Out:
# Brand: DIOR, Probability: 0.1884440531565237
# Brand: CLARINS, Probability: 0.06470550781039587
# Brand: KIEHLS, Probability: 0.06423866891035733
# Brand: CHANEL, Probability: 0.05425867309379191
# Brand: LA MER, Probability: 0.04956525255940659

# %%
markrov_brand('CLARINS')
# Out:
# Brand: CLARINS, Probability: 0.13105499174222704
# Brand: KIEHLS, Probability: 0.12971549061451798
# Brand: BOBBI BROWN, Probability: 0.08721423011482385
# Brand: WHOO, Probability: 0.08382041526882593
# Brand: ESTEE LAUDER, Probability: 0.04939058377484445

# %%
import pandas as pd
import numpy as np

def markov_brand_table(df):
    result_table = pd.DataFrame(columns=['brand_name', '1st_prob_brand', '2nd_prob_brand', '3rd_prob_brand', '4th_prob_brand', '5th_prob_brand'])

    unique_brands = sorted(set(df['brand_from']).union(set(df['brand_to'])))
    epsilon = 1e-8

    num_brands = len(unique_brands)
    transition_matrix = np.zeros((num_brands, num_brands))

    for index, row in df.iterrows():
        from_index = unique_brands.index(row['brand_from'])
        to_index = unique_brands.index(row['brand_to'])
        transition_matrix[from_index][to_index] = row['prob']

    transition_matrix = transition_matrix / (transition_matrix.sum(axis=1, keepdims=True) + epsilon)

    for brand_name in unique_brands:
        transition_matrix_smoothed = transition_matrix.copy()
        transition_matrix_smoothed[~np.isfinite(transition_matrix_smoothed)] = 0

        brand_index = unique_brands.index(brand_name)
        brand_probs_smoothed = transition_matrix_smoothed[brand_index]
        brand_probs_smoothed += epsilon
        brand_probs_normalized = brand_probs_smoothed / np.sum(brand_probs_smoothed)

        next_state_vector = np.dot(brand_probs_normalized, transition_matrix_smoothed)
        highest_prob_indices = np.argsort(-next_state_vector)[:5]

        index_to_brand = {index: brand for index, brand in enumerate(unique_brands)}
        top_5_brands = [index_to_brand.get(idx, "Unknown Brand") for idx in highest_prob_indices]

        result_table = result_table.append({
            'brand_name': brand_name,
            '1st_prob_brand': top_5_brands[0],
            '2nd_prob_brand': top_5_brands[1],
            '3rd_prob_brand': top_5_brands[2],
            '4th_prob_brand': top_5_brands[3],
            '5th_prob_brand': top_5_brands[4]
        }, ignore_index=True)

    return result_table

# Assuming df is your DataFrame containing brand transitions and probabilities
result_brand = markov_brand_table(df)

# %%
result_brand
# Out:
#           brand_name 1st_prob_brand     2nd_prob_brand 3rd_prob_brand  \
# 0    ACQUA ALLE ROSE         KIEHLS          LOCCITANE       SHISEIDO
# 1            ACSEINE        ACSEINE          LOCCITANE        CLARINS
# 2              AESOP      LOCCITANE             KIEHLS        CLARINS
# 3              ALLIE         KIEHLS            CLARINS         KANEBO
# 4             AMARIT        LE SKIN  JOJI SECRET YOUNG           SEWA
# ..               ...            ...                ...            ...
# 286           YAIMAI         YAIMAI            NURSERY        MIIMEOW
# 287         YOD SANG       YOD SANG            CLARINS           WHOO
# 288              YOU        LE SKIN               SEWA    SNAIL WHITE
# 289              YSL         KIEHLS               DIOR        CLARINS
# 290           ZELENS      LOCCITANE            CLARINS         KIEHLS
#
#     4th_prob_brand     5th_prob_brand
# 0          CLARINS               DIOR
# 1             DIOR             KIEHLS
# 2      BOBBI BROWN             LA MER
# 3           LA MER       ESTEE LAUDER
# 4            MOODS        SNAIL WHITE
# ..             ...                ...
# 286           WHOO               NUXE
# 287         KIEHLS               SEWA
# 288         KIEHLS  JOJI SECRET YOUNG
# 289   ESTEE LAUDER           SHISEIDO
# 290         LA MER           SHISEIDO
#
# [291 rows x 6 columns]

# %% [markdown]
# # Data preparation for Clustering brand behavior

# %%
import pandas as pd
import numpy as np

def markov_brand_table(df):
    result_table = pd.DataFrame(columns=['brand_name', '1st_prob', '2nd_prob', '3rd_prob', '4th_prob', '5th_prob'])

    unique_brands = sorted(set(df['brand_from']).union(set(df['brand_to'])))
    epsilon = 1e-8

    num_brands = len(unique_brands)
    transition_matrix = np.zeros((num_brands, num_brands))

    for index, row in df.iterrows():
        from_index = unique_brands.index(row['brand_from'])
        to_index = unique_brands.index(row['brand_to'])
        transition_matrix[from_index][to_index] = row['prob']

    transition_matrix = transition_matrix / (transition_matrix.sum(axis=1, keepdims=True) + epsilon)

    for brand_name in unique_brands:
        transition_matrix_smoothed = transition_matrix.copy()
        transition_matrix_smoothed[~np.isfinite(transition_matrix_smoothed)] = 0

        brand_index = unique_brands.index(brand_name)
        brand_probs_smoothed = transition_matrix_smoothed[brand_index]
        brand_probs_smoothed += epsilon
        brand_probs_normalized = brand_probs_smoothed / np.sum(brand_probs_smoothed)

        next_state_vector = np.dot(brand_probs_normalized, transition_matrix_smoothed)
        highest_prob_indices = np.argsort(-next_state_vector)[:5]
        highest_probabilities = next_state_vector[highest_prob_indices]

        result_table = result_table.append({
            'brand_name': brand_name,
            '1st_prob': highest_probabilities[0],
            '2nd_prob': highest_probabilities[1],
            '3rd_prob': highest_probabilities[2],
            '4th_prob': highest_probabilities[3],
            '5th_prob': highest_probabilities[4]
        }, ignore_index=True)

    return result_table

# Assuming df is your DataFrame containing brand transitions and probabilities
result_prob = markov_brand_table(df)

# %%
result_prob
# Out:
#           brand_name  1st_prob  2nd_prob  3rd_prob  4th_prob  5th_prob
# 0    ACQUA ALLE ROSE  0.056795  0.050906  0.050500  0.039164  0.036168
# 1            ACSEINE  0.457774  0.051307  0.042873  0.035006  0.034361
# 2              AESOP  0.119332  0.103444  0.062862  0.051998  0.048886
# 3              ALLIE  0.061769  0.054535  0.042875  0.037174  0.036206
# 4             AMARIT  0.088609  0.066614  0.066133  0.057537  0.046614
# ..               ...       ...       ...       ...       ...       ...
# 286           YAIMAI  0.339123  0.338285  0.242590  0.026667  0.026667
# 287         YOD SANG  0.059714  0.050884  0.050166  0.040792  0.037775
# 288              YOU  0.090828  0.052736  0.047843  0.046459  0.044481
# 289              YSL  0.112804  0.061837  0.061244  0.053500  0.052881
# 290           ZELENS  0.065899  0.060321  0.059452  0.053588  0.045359
#
# [291 rows x 6 columns]

# %%
result_prob.to_csv('markrov_next_prob_for_clustering.csv', index = False)

# %% [markdown]
# # Sandbox

# %%
result_prob_filter = result_prob.merge(result_brand[['brand_name', '1st_prob_brand']]
                                       , how = 'inner'
                                       , on = 'brand_name'
                                       )
result_prob_filter
# Out:
#           brand_name  1st_prob  2nd_prob  3rd_prob  4th_prob  5th_prob  \
# 0    ACQUA ALLE ROSE  0.056795  0.050906  0.050500  0.039164  0.036168
# 1            ACSEINE  0.457774  0.051307  0.042873  0.035006  0.034361
# 2              AESOP  0.119332  0.103444  0.062862  0.051998  0.048886
# 3              ALLIE  0.061769  0.054535  0.042875  0.037174  0.036206
# 4             AMARIT  0.088609  0.066614  0.066133  0.057537  0.046614
# ..               ...       ...       ...       ...       ...       ...
# 286           YAIMAI  0.339123  0.338285  0.242590  0.026667  0.026667
# 287         YOD SANG  0.059714  0.050884  0.050166  0.040792  0.037775
# 288              YOU  0.090828  0.052736  0.047843  0.046459  0.044481
# 289              YSL  0.112804  0.061837  0.061244  0.053500  0.052881
# 290           ZELENS  0.065899  0.060321  0.059452  0.053588  0.045359
#
#     1st_prob_brand
# 0           KIEHLS
# 1          ACSEINE
# 2        LOCCITANE
# 3           KIEHLS
# 4          LE SKIN
# ..             ...
# 286         YAIMAI
# 287       YOD SANG
# 288        LE SKIN
# 289         KIEHLS
# 290      LOCCITANE
#
# [291 rows x 7 columns]

# %%
result_prob_filter['mstch_first'] = np.where(result_prob_filter['brand_name'] == result_prob_filter['1st_prob_brand'],
                                            'matched', 'unmatched')
result_prob_filter
# Out:
#           brand_name  1st_prob  2nd_prob  3rd_prob  4th_prob  5th_prob  \
# 0    ACQUA ALLE ROSE  0.056795  0.050906  0.050500  0.039164  0.036168
# 1            ACSEINE  0.457774  0.051307  0.042873  0.035006  0.034361
# 2              AESOP  0.119332  0.103444  0.062862  0.051998  0.048886
# 3              ALLIE  0.061769  0.054535  0.042875  0.037174  0.036206
# 4             AMARIT  0.088609  0.066614  0.066133  0.057537  0.046614
# ..               ...       ...       ...       ...       ...       ...
# 286           YAIMAI  0.339123  0.338285  0.242590  0.026667  0.026667
# 287         YOD SANG  0.059714  0.050884  0.050166  0.040792  0.037775
# 288              YOU  0.090828  0.052736  0.047843  0.046459  0.044481
# 289              YSL  0.112804  0.061837  0.061244  0.053500  0.052881
# 290           ZELENS  0.065899  0.060321  0.059452  0.053588  0.045359
#
#     1st_prob_brand mstch_first
# 0           KIEHLS   unmatched
# 1          ACSEINE     matched
# 2        LOCCITANE   unmatched
# 3           KIEHLS   unmatched
# 4          LE SKIN   unmatched
# ..             ...         ...
# 286         YAIMAI     matched
# 287       YOD SANG     matched
# 288        LE SKIN   unmatched
# 289         KIEHLS   unmatched
# 290      LOCCITANE   unmatched
#
# [291 rows x 8 columns]

# %%
result_prob_filter.to_csv('markrov_next_prob_for_clustering.csv', index = False)

# %% [markdown]
# # Stationary Distribution

# %%
# Assuming transition_matrix is your transition matrix
epsilon = 1e-8
transition_matrix = transition_matrix / (transition_matrix.sum(axis=1, keepdims=True) + epsilon)

transition_matrix_smoothed = transition_matrix.copy()
transition_matrix_smoothed[~np.isfinite(transition_matrix_smoothed)] = 0

# Compute eigenvalues and eigenvectors of the transpose of the transition matrix
eigenvalues, eigenvectors = np.linalg.eig(transition_matrix_smoothed.T)

# Find the index of the eigenvalue closest to 1 (stationary distribution)
stationary_index = np.argmin(np.abs(eigenvalues - 1.0))
stationary_vector = np.abs(eigenvectors[:, stationary_index])
stationary_vector /= np.sum(stationary_vector)  # Normalize to ensure it's a probability distribution

# Display the stationary distribution
for brand_index, probability in enumerate(stationary_vector):
    brand = unique_brands[brand_index]  # Assuming unique_brands contains brand names
    print(f"Brand: {brand}, Probability: {probability}")
# Out:
# Brand: ACQUA ALLE ROSE, Probability: 2.227648760525039e-05
# Brand: ACSEINE, Probability: 0.0011055157232044783
# Brand: AESOP, Probability: 4.779462469548099e-05
# Brand: ALLIE, Probability: 0.00015380741304167256
# Brand: AMARIT, Probability: 0.00036015250429454246
# Brand: AMPLEN, Probability: 7.598187444823172e-05
# Brand: ANUA, Probability: 1.2149069683088347e-05
# Brand: AR, Probability: 0.0005546538183477561
# Brand: ARCHITA, Probability: 1.2454893850272234e-07
# Brand: ARDERMIS, Probability: 7.427323484253901e-06
# Brand: AREEYA, Probability: 1.204500710314118e-05
# Brand: ARGENTUM, Probability: 2.729582288643005e-07
# Brand: ARIUL, Probability: 7.040260142164544e-05
# Brand: AROMATICA, Probability: 1.0705813397572963e-06
# Brand: ARTY, Probability: 0.00022232773736760748
# Brand: ARY PROFESSIONAL, Probability: 8.457086665341833e-06
# Brand: ATREUS, Probability: 1.9732230008438265e-06
# Brand: AUGUSTINUS BADER, Probability: 0.00221525874618268
# Brand: AVEDA, Probability: 0.007379955484256907
# Brand: AVENUE BEAUTY, Probability: 0.00026895260645760043
# Brand: AWENA, Probability: 3.4303048978239175e-05
# Brand: AXISY, Probability: 4.51610029869595e-05
# Brand: BABY BRIGHT, Probability: 2.7812805463668257e-06
# Brand: BANANA BOAT, Probability: 0.0005445166730305203
# Brand: BANILA CO, Probability: 4.1870213915141775e-05
# Brand: BARENBLISS, Probability: 1.6473323717649562e-05
# Brand: BARONESS, Probability: 2.9293362043980284e-05
# Brand: BCOCO, Probability: 0.0007038524915890583
# Brand: BEAUSTA, Probability: 0.00020137077677526125
# Brand: BEAUTII BE, Probability: 4.578581561758194e-06
# Brand: BEAUTY LABO, Probability: 6.112768190207678e-06
# Brand: BEAUTY OF JOSEON, Probability: 1.6146466453156022e-06
# Brand: BEAVER, Probability: 0.0004964311408859159
# Brand: BELL TOKYO, Probability: 1.3993843585640355e-07
# Brand: BELLA AURA, Probability: 4.171429642019161e-06
# Brand: BENEFIT, Probability: 0.0005700239184285499
# Brand: BEWILD, Probability: 1.1925102905369076e-06
# Brand: BIO OIL, Probability: 0.0001225965095768772
# Brand: BIODERMA, Probability: 0.001610776035892189
# Brand: BIOTHERM, Probability: 0.03984988601879741
# Brand: BLUMEI, Probability: 3.2552317104389136e-05
# Brand: BOBBI BROWN, Probability: 0.07721897162491803
# Brand: BODY SHOP, Probability: 0.009305913005526998
# Brand: BOM, Probability: 9.103428060215592e-07
# Brand: BROWIT, Probability: 1.1087781164416967e-06
# Brand: BRUSH TOO, Probability: 3.818996570137482e-06
# Brand: BSC, Probability: 0.009002017794194734
# Brand: BULY, Probability: 0.0008684511966144409
# Brand: BUNNY FRESH, Probability: 0.0004038356505564779
# Brand: BURTS BEES, Probability: 1.4558860812575404e-05
# Brand: BY TERRY, Probability: 6.581017751949286e-05
# Brand: CATHY DOLL, Probability: 6.401586501904737e-06
# Brand: CATRICE COSMETICS, Probability: 2.9164060136996075e-06
# Brand: CAYLA, Probability: 1.9973606545371713e-06
# Brand: CELLION, Probability: 5.112009941716583e-05
# Brand: CERAVE, Probability: 0.0048616364320851774
# Brand: CETAPHIL, Probability: 0.00021626512972552526
# Brand: CHACOTT FOR PROFESSIONALS, Probability: 3.1365422015312244e-06
# Brand: CHANEL, Probability: 0.020269601476604865
# Brand: CHAONANG, Probability: 1.5366596102345424e-06
# Brand: CHARCOALOGY, Probability: 0.0004944219637709134
# Brand: CHARLOTTE TILBURY, Probability: 0.0011792439879305654
# Brand: CHAT, Probability: 1.623124229881073e-06
# Brand: CLAIRE, Probability: 0.00012419816090532317
# Brand: CLARINS, Probability: 0.047279048553613395
# Brand: CLE DE PEAU BEAUTE, Probability: 0.018597049556636974
# Brand: CLINDA MINUS, Probability: 0.00025930930362626984
# Brand: CLINIQUE, Probability: 0.027077644934698993
# Brand: COLAB DRY SHAMPOO, Probability: 0.00013086591677430613
# Brand: COREANA, Probability: 0.0
# Brand: COSLUXE, Probability: 0.00019084592625876018
# Brand: COSME DECORTE, Probability: 0.0015878457403955377
# Brand: COSMETICS 27, Probability: 8.786202468834413e-07
# Brand: COVERMARK, Probability: 0.01790102593445164
# Brand: D PROGRAM, Probability: 1.9176437903709317e-05
# Brand: DAENG GI MEO RI, Probability: 0.00015058513966008724
# Brand: DDC, Probability: 0.00021561968771573206
# Brand: DEAR KLAIRS, Probability: 3.924999613111045e-06
# Brand: DECLARE, Probability: 1.7393117850900215e-06
# Brand: DEEOM, Probability: 9.74095768231831e-07
# Brand: DEODORE, Probability: 2.4377577553401565e-05
# Brand: DERMA E, Probability: 1.5983680438107052e-06
# Brand: DERMALOGICA, Probability: 0.0005963423500692987
# Brand: DII, Probability: 1.0175137972943751e-05
# Brand: DIOR, Probability: 0.03272102911900946
# Brand: DMORNING, Probability: 6.692521871287455e-07
# Brand: EAST SKIN, Probability: 0.0003312018835359222
# Brand: ECLEAD, Probability: 1.774027865899772e-05
# Brand: EFFIN, Probability: 0.0
# Brand: ELEMIS, Probability: 0.0009104767589831625
# Brand: ELISEES, Probability: 0.0031406607701211
# Brand: ELIXIR, Probability: 0.0007868396384217497
# Brand: ELIZABETH ARDEN, Probability: 9.427690318813974e-06
# Brand: EMBRYOLISSE, Probability: 0.00022496713333917075
# Brand: ESSENCE, Probability: 3.2573798849177333e-06
# Brand: ESTAR NATURE, Probability: 2.0774265645360664e-06
# Brand: ESTEE LAUDER, Probability: 0.04927396780106898
# Brand: ETUDE, Probability: 0.0005575340713259005
# Brand: EUCERIN, Probability: 0.0025002244441874907
# Brand: EWE, Probability: 0.00015904316149034469
# Brand: FARGER, Probability: 0.0012915938242459598
# Brand: FARM STAY, Probability: 3.057556523711788e-07
# Brand: FASIO, Probability: 9.792189542731431e-05
# Brand: FEMINAE, Probability: 0.0003458402487204348
# Brand: FIIT COSMETICS & LIFESTYLE, Probability: 5.6573023248705885e-06
# Brand: FIVEISM, Probability: 1.7697588805068193e-05
# Brand: FOREO, Probability: 5.4508738185701375e-05
# Brand: FRESH, Probability: 0.0032134000169928146
# Brand: FREYJA PEAU, Probability: 0.0002645321751883452
# Brand: FUJI, Probability: 0.0004970247350340021
# Brand: GIK, Probability: 0.0007725314903557322
# Brand: GIORGIO ARMANI, Probability: 0.00020474745790410645
# Brand: GIOVANNI, Probability: 4.421787336361076e-06
# Brand: GIVENCHY, Probability: 0.0001728477664997688
# Brand: GLOW LAB, Probability: 4.78177341942376e-06
# Brand: GRAFEN, Probability: 4.453313762450139e-06
# Brand: GRATIAE, Probability: 1.751897563255352e-05
# Brand: GRAYMELIN, Probability: 4.302387186914881e-06
# Brand: GREFAS, Probability: 6.119723502733558e-05
# Brand: GROUND PLAN, Probability: 8.907320873595077e-05
# Brand: GUERLAIN, Probability: 0.0015290141400551857
# Brand: HAN JIA NE, Probability: 3.3182631246767004e-05
# Brand: HAPPY TO THE SKIN, Probability: 2.0580378937797586e-05
# Brand: HATOMUGI, Probability: 0.00026007106721283535
# Brand: HERES B2UTY, Probability: 7.431708737946595e-05
# Brand: HERMES, Probability: 0.0001914621444481303
# Brand: HOURGLASS, Probability: 0.00036540384934489355
# Brand: HUXLEY, Probability: 3.1268235134543055e-05
# Brand: ICONIC, Probability: 0.0004545157657756046
# Brand: IN2IT, Probability: 0.00031062340122771105
# Brand: IPSA, Probability: 0.0041107990070910995
# Brand: IT COSMETICS, Probability: 0.00043976873120715195
# Brand: ITS SKIN, Probability: 0.00021365962459046398
# Brand: JEJUDO, Probability: 0.0004737788493786512
# Brand: JINNAI, Probability: 7.773844487889874e-05
# Brand: JO MALONE, Probability: 0.002641203299813887
# Brand: JOJI SECRET YOUNG, Probability: 0.0030501803669145226
# Brand: JUJUNE, Probability: 0.0
# Brand: JULYME, Probability: 1.0701157727555686e-07
# Brand: JUV, Probability: 0.0002446303678045443
# Brand: JUVENA, Probability: 1.696880444355395e-06
# Brand: KANDA, Probability: 0.0003798542770579428
# Brand: KANEBO, Probability: 0.015886622462447424
# Brand: KAT BURKI, Probability: 7.875614333086427e-07
# Brand: KERASTASE, Probability: 0.00629163241516063
# Brand: KIEHLS, Probability: 0.1225394562857055
# Brand: KIKO MILANO, Probability: 4.100906088568612e-05
# Brand: KIS, Probability: 0.004055569242644583
# Brand: KISAA, Probability: 1.958087578003331e-05
# Brand: KISS MY BODY, Probability: 0.0004279463474196765
# Brand: KMA COSMETICS, Probability: 2.7923432872013875e-05
# Brand: KOSE, Probability: 0.013257231392524136
# Brand: KOTA, Probability: 0.00034879875356312676
# Brand: KRAAM, Probability: 0.0
# Brand: LA BRUKET, Probability: 0.0009805392242205311
# Brand: LA MER, Probability: 0.029006371937021488
# Brand: LA PRAIRIE, Probability: 0.002081709615338202
# Brand: LA ROCHEPOSAY, Probability: 0.009776515745068604
# Brand: LABEL YOUNG, Probability: 9.602522771420444e-07
# Brand: LALIO, Probability: 0.0006396910641906868
# Brand: LANCOME, Probability: 0.0365699915702655
# Brand: LANEIGE, Probability: 0.005357403213643757
# Brand: LAPEAK, Probability: 1.792338336174582e-05
# Brand: LAURA MERCIER, Probability: 0.00015764646028542715
# Brand: LE SKIN, Probability: 0.0035496437582395257
# Brand: LIFEFORD, Probability: 0.00022609367592163053
# Brand: LINLAMOON, Probability: 1.012892281477469e-05
# Brand: LOCCITANE, Probability: 0.08629076882744428
# Brand: LOHACELL, Probability: 9.976266577749908e-06
# Brand: LOREAL, Probability: 2.0036979786375448e-05
# Brand: MAC, Probability: 0.0028016620131213455
# Brand: MADELYN, Probability: 0.0007629002112469138
# Brand: MALISSA KISS, Probability: 0.00015368691527636432
# Brand: MAMI, Probability: 2.0038810475061257e-05
# Brand: MARIA NATURAL BEAUTY, Probability: 5.248712241686944e-06
# Brand: MARKS & SPENCER, Probability: 0.013413820920426584
# Brand: MEIJICREAM, Probability: 8.420972405200266e-05
# Brand: MERREZCA, Probability: 9.788399603966439e-05
# Brand: MIIMEOW, Probability: 3.578686155615346e-05
# Brand: MILLE, Probability: 0.00016780018669660125
# Brand: MISTINE, Probability: 4.603629410566808e-05
# Brand: MIZUMI, Probability: 0.0002882204169227023
# Brand: MOODS, Probability: 0.0030604135110911
# Brand: MORINGA PROJECT, Probability: 2.6470572614063474e-05
# Brand: MZ SKIN, Probability: 6.066659437315049e-07
# Brand: N LIFEPLUS, Probability: 0.0
# Brand: NARS, Probability: 0.0003459440534164785
# Brand: NATURE BALANCE, Probability: 0.00016927462795678688
# Brand: NATURE REPUBLIC, Probability: 5.7239246832118335e-05
# Brand: NEOSTRATA, Probability: 0.000977939194738695
# Brand: NOVEXPERT, Probability: 6.210962026167622e-05
# Brand: NURSERY, Probability: 4.764385113296554e-05
# Brand: NUXE, Probability: 0.000286538628757878
# Brand: OHANA MAHAALO, Probability: 4.747277438150875e-07
# Brand: OLAPLEX, Probability: 9.986028026900098e-05
# Brand: OLAY, Probability: 7.110685875134695e-07
# Brand: OLIVE YOUNG, Probability: 0.00011210564254667098
# Brand: OLYSEE, Probability: 1.2211904075157578e-06
# Brand: ONE THING, Probability: 5.417611515677226e-06
# Brand: ONGREDIENTS, Probability: 0.000109080161311062
# Brand: ORIGINS, Probability: 0.013677799570469086
# Brand: OXECURE, Probability: 0.0013648942270958018
# Brand: PAN COSMETICS, Probability: 0.00419786170580019
# Brand: PAN DERMACARE, Probability: 0.0036553357170141746
# Brand: PAN SPA TECH, Probability: 0.000827500214597487
# Brand: PANACEE, Probability: 4.0677242789842684e-05
# Brand: PANIER DES SENS, Probability: 0.00012990315985528353
# Brand: PAUL & JOE, Probability: 3.50328647859967e-05
# Brand: PAYOT, Probability: 0.00015684165011420592
# Brand: PHILOSOPHY, Probability: 0.00022270240315647803
# Brand: PHYTO, Probability: 0.0007612245488186626
# Brand: PLANTNERY, Probability: 0.00046072108111485044
# Brand: POLA, Probability: 0.000916177686355978
# Brand: PRALYN, Probability: 9.507068672715243e-07
# Brand: PREMIER, Probability: 0.0011039753277487432
# Brand: PRETTYSKIN, Probability: 1.1295560072993037e-05
# Brand: PURE CARE, Probability: 0.0014264062765134086
# Brand: PURIFECT, Probability: 1.475421127016807e-05
# Brand: RATI, Probability: 1.4011758505578775e-07
# Brand: REPECHAGE, Probability: 0.002357141781964325
# Brand: RESTORIA, Probability: 3.505174721570575e-05
# Brand: REVLON, Probability: 0.0035134618414474073
# Brand: REVOLUTION, Probability: 6.875189757126228e-06
# Brand: REVOX B77, Probability: 5.531346915484676e-05
# Brand: ROUND LAB, Probability: 1.8808713130384057e-05
# Brand: SABAI AROM, Probability: 1.426524665021763e-07
# Brand: SEBAMED, Probability: 5.641453986817547e-05
# Brand: SENKA, Probability: 0.000520653680068513
# Brand: SEWA, Probability: 0.003671554494120654
# Brand: SEXYHAIR, Probability: 7.195038882988515e-05
# Brand: SHEENE, Probability: 0.00012913989222222515
# Brand: SHIJILIREN, Probability: 4.499675273649726e-07
# Brand: SHISEIDO, Probability: 0.04487594618437948
# Brand: SHU UEMURA, Probability: 0.0029891436458928107
# Brand: SIORIS, Probability: 1.3569927095725557e-07
# Brand: SISLEY, Probability: 0.0075567773655840186
# Brand: SIVANNA COLORS, Probability: 0.00021526221998586435
# Brand: SIXTORY, Probability: 1.4243723218177061e-05
# Brand: SK-II, Probability: 0.017700087511853913
# Brand: SKIN SYRUP, Probability: 1.22841781197937e-05
# Brand: SKIN1004, Probability: 0.000214836001993177
# Brand: SKINFOOD NEW ZEALAND, Probability: 5.631616789937009e-07
# Brand: SKINOXY, Probability: 0.0002834448515939452
# Brand: SKINRX LAB, Probability: 1.3752648369695215e-05
# Brand: SKINSISTA, Probability: 9.139392213668282e-05
# Brand: SKYNLAB, Probability: 1.405982984890582e-07
# Brand: SNAIL WHITE, Probability: 0.0018198449799968533
# Brand: SOBIO ETIC, Probability: 6.3395949503968315e-06
# Brand: SOLLIE, Probability: 6.292472847568405e-05
# Brand: SOLURE, Probability: 1.7233403592543387e-05
# Brand: SOS, Probability: 0.00047283775860532053
# Brand: SPELLA, Probability: 1.1043125459516204e-06
# Brand: ST ANDREWS, Probability: 0.0003683234809760462
# Brand: SUGAR & PEPPER, Probability: 2.4690931498652934e-05
# Brand: SUISAI, Probability: 7.678032753608542e-05
# Brand: SULWHASOO, Probability: 0.010345913717901981
# Brand: SUQQU, Probability: 0.004756803507666866
# Brand: SUSANNE KAUFMANN, Probability: 1.2860801018882128e-05
# Brand: TALIKA, Probability: 2.9641153546127433e-06
# Brand: TELLME, Probability: 0.002025046445468429
# Brand: TENZERO, Probability: 0.0011403598400080578
# Brand: TERAPIC, Probability: 2.2905494805883964e-06
# Brand: THA BY NONGCHAT, Probability: 0.0
# Brand: THAYERS, Probability: 0.000256434483534018
# Brand: THE 28, Probability: 4.262046542888977e-05
# Brand: THELAB, Probability: 3.088735090472571e-05
# Brand: THERMOCEUTICAL, Probability: 1.0342091870060782e-05
# Brand: THREE, Probability: 0.005797888412668999
# Brand: TOM FORD, Probability: 0.0003903601206862581
# Brand: TOPPIK, Probability: 6.947502636339742e-05
# Brand: TORMONTO, Probability: 0.0
# Brand: TOUGH & TUMBLE, Probability: 0.0
# Brand: TREE HUT, Probability: 0.00012696030800657897
# Brand: TRILOGY, Probability: 4.90233320305288e-05
# Brand: ULTIMA II, Probability: 0.0003160626295608687
# Brand: USTAR, Probability: 7.988861674297456e-06
# Brand: VALMONT, Probability: 0.00013582922679482615
# Brand: VARENN, Probability: 1.1771400387144308e-05
# Brand: VICHY, Probability: 0.001107522962641722
# Brand: WE ARE FEEL GOOD INC, Probability: 3.731772036596538e-05
# Brand: WELLAGE, Probability: 9.755590550259951e-05
# Brand: WHOO, Probability: 0.08542627346867497
# Brand: WILD FERNS, Probability: 2.209650751925389e-05
# Brand: WILMASCHUMANN, Probability: 6.779983176115307e-05
# Brand: WOW SKIN SCIENCE, Probability: 3.9542670477089994e-05
# Brand: X CUTE ME, Probability: 1.197223262161999e-06
# Brand: YAIMAI, Probability: 4.7356557289807006e-05
# Brand: YOD SANG, Probability: 4.499715417767874e-05
# Brand: YOU, Probability: 2.5200595050684717e-05
# Brand: YSL, Probability: 0.0027902814243300983
# Brand: ZELENS, Probability: 1.3276581669957154e-05

# %%
tab = pd.DataFrame(columns=['brand_name', 'stationary_prob'])

# Assuming transition_matrix is your transition matrix
epsilon = 1e-8
transition_matrix = transition_matrix / (transition_matrix.sum(axis=1, keepdims=True) + epsilon)

transition_matrix_smoothed = transition_matrix.copy()
transition_matrix_smoothed[~np.isfinite(transition_matrix_smoothed)] = 0

# Compute eigenvalues and eigenvectors of the transpose of the transition matrix
eigenvalues, eigenvectors = np.linalg.eig(transition_matrix_smoothed.T)

# Find the index of the eigenvalue closest to 1 (stationary distribution)
stationary_index = np.argmin(np.abs(eigenvalues - 1.0))
stationary_vector = np.abs(eigenvectors[:, stationary_index])
stationary_vector /= np.sum(stationary_vector)  # Normalize to ensure it's a probability distribution

# Display the stationary distribution
for brand_index, probability in enumerate(stationary_vector):
    brand = unique_brands[brand_index]  # Assuming unique_brands contains brand names

    tab = tab.append({
        'brand_name': brand
        , 'stationary_prob': probability
        }, ignore_index=True)

# %%
tab.sort_values('stationary_prob', ascending = False)
# Out:
#           brand_name  stationary_prob
# 145           KIEHLS         0.122539
# 167        LOCCITANE         0.086291
# 281             WHOO         0.085426
# 41       BOBBI BROWN         0.077219
# 96      ESTEE LAUDER         0.049274
# ..               ...              ...
# 271   TOUGH & TUMBLE         0.000000
# 153            KRAAM         0.000000
# 270         TORMONTO         0.000000
# 185       N LIFEPLUS         0.000000
# 262  THA BY NONGCHAT         0.000000
#
# [291 rows x 2 columns]

# %%
tab[tab['brand_name'] == 'CHANEL']
# Out:
#    brand_name  stationary_prob
# 58     CHANEL          0.02027
